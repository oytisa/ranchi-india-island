# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import rasterio as rs

# %%
src_img = r'C:\SagarIsland\SagarIslandImages\AWEI_Images\awei_transform_2020.png'

# %%
color_im = cv.imread(src_img)
im = cv.imread(src_img, cv.IMREAD_GRAYSCALE)
#im = im[329:1029,777:1229]

# %%
type(im)
# Out:
# numpy.ndarray

# %%
im_np = array = im.read(1)

# %%
im = im.astype("uint8")

# %%
#imgray = cv.cvtColor(im, cv.COLOR_BGR2GRAY)
ret, thresh = cv.threshold(im, 0, 255, cv.THRESH_BINARY+cv.THRESH_OTSU)

# %%
im.shape
# Out:
# (700, 452, 3)

# %%
imok = cv.cvtColor(im, cv.COLOR_BGR2RGB)

# %%
imok.shape
# Out:
# (700, 452, 3)

# %%
fig, ax = plt.subplots()
plot_im = ax.imshow(thresh)

# %%
cv.imwrite("C:/Images/otsu.jpg", thresh)
# Out:
# True

# %%
contours, hierarchy = cv.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# %%
shoreline = cv.drawContours(color_im, contours, 127, (255,255,255), 1)

# %%
fig, ax = plt.subplots()
plot_im = ax.imshow(shoreline)

# %%
len(contours)
# Out:
# 160

# %%
hierarchy
# Out:
# array([[[  1,  -1,  -1,  -1],
#         [  2,   0,  -1,  -1],
#         [  3,   1,  -1,  -1],
#         [  4,   2,  -1,  -1],
#         [  5,   3,  -1,  -1],
#         [  6,   4,  -1,  -1],
#         [  7,   5,  -1,  -1],
#         [  8,   6,  -1,  -1],
#         [  9,   7,  -1,  -1],
#         [ 10,   8,  -1,  -1],
#         [ 11,   9,  -1,  -1],
#         [ 12,  10,  -1,  -1],
#         [ 13,  11,  -1,  -1],
#         [ 14,  12,  -1,  -1],
#         [ 15,  13,  -1,  -1],
#         [ 16,  14,  -1,  -1],
#         [ 17,  15,  -1,  -1],
#         [ 18,  16,  -1,  -1],
#         [ 19,  17,  -1,  -1],
#         [ 20,  18,  -1,  -1],
#         [ 21,  19,  -1,  -1],
#         [ 22,  20,  -1,  -1],
#         [ 23,  21,  -1,  -1],
#         [ 24,  22,  -1,  -1],
#         [ 25,  23,  -1,  -1],
#         [ 26,  24,  -1,  -1],
#         [ 27,  25,  -1,  -1],
#         [ 28,  26,  -1,  -1],
#         [ 29,  27,  -1,  -1],
#         [ 31,  28,  30,  -1],
#         [ -1,  -1,  -1,  29],
# ...

# %%
perimeters = np.zeros((len(contours),))

# %%
for i in range(len(contours)) :
    c= contours[i]
    p = cv.arcLength(c,True)
    perimeters[i] = p

# %%
max_contours_idx = np.argsort(perimeters)[-2]
max_contours_idx
# Out:
# 127

# %%
cv.imwrite('C:/Images/costa.png', shoreline)
# Out:
# True
